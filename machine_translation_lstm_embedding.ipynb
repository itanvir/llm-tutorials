# %%
import numpy as np
import tensorflow as tf
import random
import matplotlib.pyplot as plt
plt.style.use('ggplot')

seed = 50
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## LSTM example: Machine translation

# %% [markdown]
# ### Data

# %%
from num2words import num2words

def create_french_to_english_data():
    start = 1
    end = 1000
    
    # Create the dataset
    source = []
    target = []
    for i in range(start, end+1):
        # Convert the number to words in French
        words = '<start> ' + num2words(i, lang='fr') + ' <end>'
        source.append(words)
        words = '<start> ' + num2words(i, lang='en') + ' <end>'
        target.append(words)
    
    return source, target

# %%
source, target = create_french_to_english_data()

# %%
from sklearn.model_selection import train_test_split

def split_data(source, target):

    train_source, test_source, train_target, test_target = train_test_split(
        source, target, test_size=0.2, random_state=42
    )

    return train_source, test_source, train_target, test_target

# %%
train_source, test_source, train_target, test_target = split_data(source, target)

# %% [markdown]
# ### Prepare sequences

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(oov_token="<OOV>", filters='!"#$%&()*+,-./:;=?@[\\]^_`{|}~\t\n')
tokenizer.fit_on_texts(train_source + train_target)

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences

def prepare_sequences(source, target, tokenizer):
    """
    Prepare the input and output sequences for training the model.

    Parameters:
    dataset (list): The dataset to be processed.
    tokenizer (Tokenizer): The tokenizer to be used.

    Returns:
    tuple: The prepared input and output sequences.
    """


    X_encoder = tokenizer.texts_to_sequences(source)

    Y_encoded = tokenizer.texts_to_sequences(target)
    Y_decoder_input = Y_encoded
    Y_decoder_output = [encoded[1:] + [0] for encoded in Y_encoded]
    
    X_encoder = pad_sequences(X_encoder, maxlen=8, padding='post', truncating='post', dtype='float32')
    Y_decoder_input = pad_sequences(Y_decoder_input, maxlen=8, padding='post', truncating='post', dtype='float32')
    Y_decoder_output = pad_sequences(Y_decoder_output, maxlen=8, padding='post', truncating='post', dtype='float32')

    return X_encoder, Y_decoder_input, Y_decoder_output

# %%
X_train_encoder, Y_train_decoder_input, Y_train_decoder_output = prepare_sequences(train_source, train_target, tokenizer)
X_test_encoder, Y_test_decoder_input, Y_test_decoder_output = prepare_sequences(test_source, test_target, tokenizer)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding, CategoryEncoding
from tensorflow.keras.models import Model


def create_lstm_encoder_decoder_model(
    encoder_vocab_size, decoder_vocab_size, embedding_dim, seq_length
):

    # Encoder
    encoder_inputs = Input(shape=(seq_length,), name="encoder_inputs")
    encoder_embedding = Embedding(
        input_dim=encoder_vocab_size, output_dim=embedding_dim, name="encoder_embedding"
    )(encoder_inputs)
    encoder_lstm, state_h, state_c = LSTM(
        units=lstm_units, return_state=True, name="encoder_lstm"
    )(encoder_embedding)
    encoder_states = [state_h, state_c]

    # Decoder
    decoder_inputs = Input(shape=(seq_length,), name="decoder_inputs")
    decoder_embedding = Embedding(
        input_dim=decoder_vocab_size, output_dim=embedding_dim, name="decoder_embedding"
    )(decoder_inputs)
    decoder_lstm, _, _ = LSTM(
        units=lstm_units, return_sequences=True, return_state=True, name="decoder_lstm"
    )(decoder_embedding, initial_state=encoder_states)
    decoder_dense = Dense(
        units=decoder_vocab_size, activation="softmax", name="decoder_dense"
    )
    decoder_outputs = decoder_dense(decoder_lstm)

    # Model
    model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
    model.compile(
        optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
    )

    # Display the model summary
    model.summary(line_length=120)

    return model

# %%
# Assuming vocabulary sizes are known
encoder_vocab_size = 59  # Change this to your actual encoder vocabulary size
decoder_vocab_size = 59  # Change this to your actual decoder vocabulary size
embedding_dim = 256  # Dimension of the embedding vectors
lstm_units = 512  # Number of LSTM units
seq_length = 8  # Sequence length for both encoder and decoder

model = create_lstm_encoder_decoder_model(encoder_vocab_size, decoder_vocab_size, embedding_dim, seq_length)
# Out:
# 2024-06-12 20:42:58.857366: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Max
# 2024-06-12 20:42:58.857391: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2024-06-12 20:42:58.857398: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2024-06-12 20:42:58.857429: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-06-12 20:42:58.857447: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "model"
# ________________________________________________________________________________________________________________________
#  Layer (type)                       Output Shape                        Param #     Connected to
# ========================================================================================================================
#  encoder_inputs (InputLayer)        [(None, 8)]                         0           []
#
#  decoder_inputs (InputLayer)        [(None, 8)]                         0           []
#
#  encoder_embedding (Embedding)      (None, 8, 256)                      15104       ['encoder_inputs[0][0]']
#
#  decoder_embedding (Embedding)      (None, 8, 256)                      15104       ['decoder_inputs[0][0]']
#
#  encoder_lstm (LSTM)                [(None, 512),                       1574912     ['encoder_embedding[0][0]']
#                                      (None, 512),
#                                      (None, 512)]
#
#  decoder_lstm (LSTM)                [(None, 8, 512),                    1574912     ['decoder_embedding[0][0]',
#                                      (None, 512),                                    'encoder_lstm[0][1]',
#                                      (None, 512)]                                    'encoder_lstm[0][2]']
#
#  decoder_dense (Dense)              (None, 8, 59)                       30267       ['decoder_lstm[0][0]']
#
# ========================================================================================================================
# Total params: 3210299 (12.25 MB)
# Trainable params: 3210299 (12.25 MB)
# Non-trainable params: 0 (0.00 Byte)
# ________________________________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

callback_es = EarlyStopping(monitor='val_loss', patience=20)
history = model.fit(
    [X_train_encoder, Y_train_decoder_input],
    Y_train_decoder_output,
    batch_size=64,
    epochs=500,
    validation_split=0.2,
    callbacks=[callback_es]
)
# Out:
# Epoch 1/500
# 2024-06-12 20:43:00.729847: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - 5s 111ms/step - loss: 3.2527 - accuracy: 0.2955 - val_loss: 2.3830 - val_accuracy: 0.2242
# Epoch 2/500
# 10/10 [==============================] - 0s 16ms/step - loss: 2.1186 - accuracy: 0.4758 - val_loss: 1.8411 - val_accuracy: 0.6359
# Epoch 3/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.7297 - accuracy: 0.6107 - val_loss: 1.5831 - val_accuracy: 0.5813
# Epoch 4/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.4868 - accuracy: 0.6324 - val_loss: 1.3441 - val_accuracy: 0.6609
# Epoch 5/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.2186 - accuracy: 0.6650 - val_loss: 1.0824 - val_accuracy: 0.6812
# Epoch 6/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.9819 - accuracy: 0.6910 - val_loss: 0.9077 - val_accuracy: 0.7055
# Epoch 7/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.8804 - accuracy: 0.7066 - val_loss: 0.8545 - val_accuracy: 0.7063
# Epoch 8/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.8375 - accuracy: 0.7125 - val_loss: 0.8484 - val_accuracy: 0.7016
# Epoch 9/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.8079 - accuracy: 0.7121 - val_loss: 0.8026 - val_accuracy: 0.7156
# Epoch 10/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.7737 - accuracy: 0.7195 - val_loss: 0.7752 - val_accuracy: 0.7164
# Epoch 11/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.7435 - accuracy: 0.7330 - val_loss: 0.7509 - val_accuracy: 0.7352
# Epoch 12/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.7177 - accuracy: 0.7377 - val_loss: 0.7320 - val_accuracy: 0.7422
# Epoch 13/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.6902 - accuracy: 0.7510 - val_loss: 0.7086 - val_accuracy: 0.7359
# Epoch 14/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.6675 - accuracy: 0.7543 - val_loss: 0.6984 - val_accuracy: 0.7500
# Epoch 15/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.6673 - accuracy: 0.7580 - val_loss: 0.7018 - val_accuracy: 0.7523
# Epoch 16/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.6414 - accuracy: 0.7592 - val_loss: 0.6572 - val_accuracy: 0.7594
# Epoch 17/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.6129 - accuracy: 0.7693 - val_loss: 0.6400 - val_accuracy: 0.7633
# Epoch 18/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5907 - accuracy: 0.7797 - val_loss: 0.6231 - val_accuracy: 0.7758
# Epoch 19/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5690 - accuracy: 0.7871 - val_loss: 0.6040 - val_accuracy: 0.7812
# Epoch 20/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5516 - accuracy: 0.8023 - val_loss: 0.6079 - val_accuracy: 0.7711
# Epoch 21/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5573 - accuracy: 0.7975 - val_loss: 0.6269 - val_accuracy: 0.7719
# Epoch 22/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5631 - accuracy: 0.7965 - val_loss: 0.5714 - val_accuracy: 0.7898
# Epoch 23/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5583 - accuracy: 0.7912 - val_loss: 0.5627 - val_accuracy: 0.7937
# Epoch 24/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5420 - accuracy: 0.8096 - val_loss: 0.5624 - val_accuracy: 0.7937
# Epoch 25/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.4989 - accuracy: 0.8230 - val_loss: 0.5299 - val_accuracy: 0.8109
# Epoch 26/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.4730 - accuracy: 0.8357 - val_loss: 0.5132 - val_accuracy: 0.8227
# Epoch 27/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.4481 - accuracy: 0.8480 - val_loss: 0.4800 - val_accuracy: 0.8297
# Epoch 28/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.4359 - accuracy: 0.8445 - val_loss: 0.4640 - val_accuracy: 0.8383
# Epoch 29/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.4128 - accuracy: 0.8613 - val_loss: 0.4525 - val_accuracy: 0.8508
# Epoch 30/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.3878 - accuracy: 0.8676 - val_loss: 0.4530 - val_accuracy: 0.8430
# Epoch 31/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.3726 - accuracy: 0.8730 - val_loss: 0.4143 - val_accuracy: 0.8531
# Epoch 32/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.3562 - accuracy: 0.8805 - val_loss: 0.4085 - val_accuracy: 0.8672
# Epoch 33/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.3423 - accuracy: 0.8895 - val_loss: 0.4018 - val_accuracy: 0.8672
# Epoch 34/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.3219 - accuracy: 0.8922 - val_loss: 0.3758 - val_accuracy: 0.8719
# Epoch 35/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.2983 - accuracy: 0.8990 - val_loss: 0.3437 - val_accuracy: 0.8852
# Epoch 36/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.2827 - accuracy: 0.9029 - val_loss: 0.3978 - val_accuracy: 0.8523
# Epoch 37/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2829 - accuracy: 0.9018 - val_loss: 0.3227 - val_accuracy: 0.8805
# Epoch 38/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.2556 - accuracy: 0.9141 - val_loss: 0.3193 - val_accuracy: 0.8797
# Epoch 39/500
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2379 - accuracy: 0.9199 - val_loss: 0.2981 - val_accuracy: 0.8852
# Epoch 40/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.2189 - accuracy: 0.9268 - val_loss: 0.2904 - val_accuracy: 0.8914
# Epoch 41/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.2107 - accuracy: 0.9305 - val_loss: 0.2549 - val_accuracy: 0.9039
# Epoch 42/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.1862 - accuracy: 0.9412 - val_loss: 0.2463 - val_accuracy: 0.9141
# Epoch 43/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1666 - accuracy: 0.9504 - val_loss: 0.2330 - val_accuracy: 0.9125
# Epoch 44/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1498 - accuracy: 0.9551 - val_loss: 0.2087 - val_accuracy: 0.9242
# Epoch 45/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1342 - accuracy: 0.9625 - val_loss: 0.1942 - val_accuracy: 0.9289
# Epoch 46/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1194 - accuracy: 0.9666 - val_loss: 0.1935 - val_accuracy: 0.9250
# Epoch 47/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1073 - accuracy: 0.9748 - val_loss: 0.1746 - val_accuracy: 0.9406
# Epoch 48/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0968 - accuracy: 0.9764 - val_loss: 0.1640 - val_accuracy: 0.9375
# Epoch 49/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0908 - accuracy: 0.9785 - val_loss: 0.1500 - val_accuracy: 0.9500
# Epoch 50/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0756 - accuracy: 0.9832 - val_loss: 0.1438 - val_accuracy: 0.9492
# Epoch 51/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0692 - accuracy: 0.9859 - val_loss: 0.1249 - val_accuracy: 0.9555
# Epoch 52/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0593 - accuracy: 0.9902 - val_loss: 0.1201 - val_accuracy: 0.9648
# Epoch 53/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0553 - accuracy: 0.9887 - val_loss: 0.1006 - val_accuracy: 0.9789
# Epoch 54/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0488 - accuracy: 0.9916 - val_loss: 0.0957 - val_accuracy: 0.9734
# Epoch 55/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0421 - accuracy: 0.9928 - val_loss: 0.1262 - val_accuracy: 0.9586
# Epoch 56/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0515 - accuracy: 0.9871 - val_loss: 0.1188 - val_accuracy: 0.9641
# Epoch 57/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0498 - accuracy: 0.9881 - val_loss: 0.0914 - val_accuracy: 0.9727
# Epoch 58/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0497 - accuracy: 0.9896 - val_loss: 0.0976 - val_accuracy: 0.9711
# Epoch 59/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0458 - accuracy: 0.9898 - val_loss: 0.1002 - val_accuracy: 0.9758
# Epoch 60/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0316 - accuracy: 0.9961 - val_loss: 0.0850 - val_accuracy: 0.9805
# Epoch 61/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0253 - accuracy: 0.9980 - val_loss: 0.0725 - val_accuracy: 0.9781
# Epoch 62/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0197 - accuracy: 0.9980 - val_loss: 0.0561 - val_accuracy: 0.9875
# Epoch 63/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0141 - accuracy: 0.9994 - val_loss: 0.0573 - val_accuracy: 0.9875
# Epoch 64/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0154 - accuracy: 0.9980 - val_loss: 0.0612 - val_accuracy: 0.9867
# Epoch 65/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0144 - accuracy: 0.9982 - val_loss: 0.0593 - val_accuracy: 0.9883
# Epoch 66/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0115 - accuracy: 0.9998 - val_loss: 0.0494 - val_accuracy: 0.9914
# Epoch 67/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0093 - accuracy: 0.9998 - val_loss: 0.0460 - val_accuracy: 0.9898
# Epoch 68/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0459 - val_accuracy: 0.9906
# Epoch 69/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9914
# Epoch 70/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 0.9914
# Epoch 71/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9914
# Epoch 72/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9922
# Epoch 73/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9914
# Epoch 74/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9922
# Epoch 75/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9906
# Epoch 76/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0374 - val_accuracy: 0.9914
# Epoch 77/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9914
# Epoch 78/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9922
# Epoch 79/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9922
# Epoch 80/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0365 - val_accuracy: 0.9914
# Epoch 81/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0364 - val_accuracy: 0.9922
# Epoch 82/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0361 - val_accuracy: 0.9922
# Epoch 83/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0355 - val_accuracy: 0.9922
# Epoch 84/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0353 - val_accuracy: 0.9922
# Epoch 85/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0353 - val_accuracy: 0.9922
# Epoch 86/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 0.9922
# Epoch 87/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9922
# Epoch 88/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.9922
# Epoch 89/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9922
# Epoch 90/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9922
# Epoch 91/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0337 - val_accuracy: 0.9922
# Epoch 92/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 0.9922
# Epoch 93/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9922
# Epoch 94/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 0.9922
# Epoch 95/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 0.9922
# Epoch 96/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0329 - val_accuracy: 0.9922
# Epoch 97/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 0.9922
# Epoch 98/500
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0324 - val_accuracy: 0.9922
# Epoch 99/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0322 - val_accuracy: 0.9922
# Epoch 100/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0323 - val_accuracy: 0.9922
# Epoch 101/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 0.9922
# Epoch 102/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 0.9922
# Epoch 103/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 0.9922
# Epoch 104/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0315 - val_accuracy: 0.9922
# Epoch 105/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0312 - val_accuracy: 0.9922
# Epoch 106/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0311 - val_accuracy: 0.9922
# Epoch 107/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0312 - val_accuracy: 0.9922
# Epoch 108/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9922
# Epoch 109/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 0.9922
# Epoch 110/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 0.9930
# Epoch 111/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0305 - val_accuracy: 0.9922
# Epoch 112/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0302 - val_accuracy: 0.9922
# Epoch 113/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0302 - val_accuracy: 0.9930
# Epoch 114/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0302 - val_accuracy: 0.9922
# Epoch 115/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 0.9930
# Epoch 116/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 0.9930
# Epoch 117/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0298 - val_accuracy: 0.9930
# Epoch 118/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0295 - val_accuracy: 0.9930
# Epoch 119/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0298 - val_accuracy: 0.9930
# Epoch 120/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 0.9930
# Epoch 121/500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 0.9930
# Epoch 122/500
# 10/10 [==============================] - 0s 12ms/step - loss: 9.8134e-04 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 0.9930
# Epoch 123/500
# 10/10 [==============================] - 0s 12ms/step - loss: 9.6263e-04 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 0.9930
# Epoch 124/500
# 10/10 [==============================] - 0s 12ms/step - loss: 9.4230e-04 - accuracy: 1.0000 - val_loss: 0.0290 - val_accuracy: 0.9930
# Epoch 125/500
# 10/10 [==============================] - 0s 12ms/step - loss: 9.2390e-04 - accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 0.9930
# Epoch 126/500
# 10/10 [==============================] - 0s 12ms/step - loss: 9.0444e-04 - accuracy: 1.0000 - val_loss: 0.0288 - val_accuracy: 0.9930
# Epoch 127/500
# 10/10 [==============================] - 0s 12ms/step - loss: 8.8679e-04 - accuracy: 1.0000 - val_loss: 0.0287 - val_accuracy: 0.9930
# Epoch 128/500
# 10/10 [==============================] - 0s 13ms/step - loss: 8.6988e-04 - accuracy: 1.0000 - val_loss: 0.0287 - val_accuracy: 0.9930
# Epoch 129/500
# 10/10 [==============================] - 0s 13ms/step - loss: 8.5394e-04 - accuracy: 1.0000 - val_loss: 0.0286 - val_accuracy: 0.9930
# Epoch 130/500
# 10/10 [==============================] - 0s 13ms/step - loss: 8.3817e-04 - accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9930
# Epoch 131/500
# 10/10 [==============================] - 0s 12ms/step - loss: 8.2113e-04 - accuracy: 1.0000 - val_loss: 0.0284 - val_accuracy: 0.9930
# Epoch 132/500
# 10/10 [==============================] - 0s 12ms/step - loss: 8.0639e-04 - accuracy: 1.0000 - val_loss: 0.0284 - val_accuracy: 0.9930
# Epoch 133/500
# 10/10 [==============================] - 0s 11ms/step - loss: 7.9205e-04 - accuracy: 1.0000 - val_loss: 0.0282 - val_accuracy: 0.9930
# Epoch 134/500
# 10/10 [==============================] - 0s 11ms/step - loss: 7.7657e-04 - accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 0.9930
# Epoch 135/500
# 10/10 [==============================] - 0s 12ms/step - loss: 7.6273e-04 - accuracy: 1.0000 - val_loss: 0.0280 - val_accuracy: 0.9930
# Epoch 136/500
# 10/10 [==============================] - 0s 12ms/step - loss: 7.4874e-04 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9930
# Epoch 137/500
# 10/10 [==============================] - 0s 12ms/step - loss: 7.3675e-04 - accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 0.9930
# Epoch 138/500
# 10/10 [==============================] - 0s 12ms/step - loss: 7.2300e-04 - accuracy: 1.0000 - val_loss: 0.0278 - val_accuracy: 0.9930
# Epoch 139/500
# 10/10 [==============================] - 0s 13ms/step - loss: 7.1056e-04 - accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 0.9930
# Epoch 140/500
# 10/10 [==============================] - 0s 12ms/step - loss: 6.9860e-04 - accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 0.9930
# Epoch 141/500
# 10/10 [==============================] - 0s 11ms/step - loss: 6.8477e-04 - accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 0.9930
# Epoch 142/500
# 10/10 [==============================] - 0s 12ms/step - loss: 6.7349e-04 - accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 0.9930
# Epoch 143/500
# 10/10 [==============================] - 0s 12ms/step - loss: 6.6253e-04 - accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 0.9930
# Epoch 144/500
# 10/10 [==============================] - 0s 13ms/step - loss: 6.5213e-04 - accuracy: 1.0000 - val_loss: 0.0274 - val_accuracy: 0.9930
# Epoch 145/500
# 10/10 [==============================] - 0s 12ms/step - loss: 6.4057e-04 - accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 0.9930
# Epoch 146/500
# 10/10 [==============================] - 0s 12ms/step - loss: 6.3028e-04 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9930
# Epoch 147/500
# 10/10 [==============================] - 0s 12ms/step - loss: 6.1983e-04 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9930
# Epoch 148/500
# 10/10 [==============================] - 0s 13ms/step - loss: 6.1041e-04 - accuracy: 1.0000 - val_loss: 0.0270 - val_accuracy: 0.9930
# Epoch 149/500
# 10/10 [==============================] - 0s 12ms/step - loss: 5.9998e-04 - accuracy: 1.0000 - val_loss: 0.0271 - val_accuracy: 0.9930
# Epoch 150/500
# 10/10 [==============================] - 0s 12ms/step - loss: 5.9050e-04 - accuracy: 1.0000 - val_loss: 0.0270 - val_accuracy: 0.9930
# Epoch 151/500
# 10/10 [==============================] - 0s 12ms/step - loss: 5.8163e-04 - accuracy: 1.0000 - val_loss: 0.0271 - val_accuracy: 0.9930
# Epoch 152/500
# 10/10 [==============================] - 0s 11ms/step - loss: 5.7185e-04 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 0.9930
# Epoch 153/500
# 10/10 [==============================] - 0s 12ms/step - loss: 5.6318e-04 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 0.9930
# Epoch 154/500
# 10/10 [==============================] - 0s 11ms/step - loss: 5.5398e-04 - accuracy: 1.0000 - val_loss: 0.0267 - val_accuracy: 0.9930
# Epoch 155/500
# 10/10 [==============================] - 0s 10ms/step - loss: 5.4587e-04 - accuracy: 1.0000 - val_loss: 0.0266 - val_accuracy: 0.9930
# Epoch 156/500
# 10/10 [==============================] - 0s 12ms/step - loss: 5.3767e-04 - accuracy: 1.0000 - val_loss: 0.0267 - val_accuracy: 0.9930
# Epoch 157/500
# 10/10 [==============================] - 0s 12ms/step - loss: 5.2882e-04 - accuracy: 1.0000 - val_loss: 0.0266 - val_accuracy: 0.9930
# Epoch 158/500
# 10/10 [==============================] - 0s 12ms/step - loss: 5.2102e-04 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9930
# Epoch 159/500
# 10/10 [==============================] - 0s 12ms/step - loss: 5.1376e-04 - accuracy: 1.0000 - val_loss: 0.0264 - val_accuracy: 0.9930
# Epoch 160/500
# 10/10 [==============================] - 0s 12ms/step - loss: 5.0552e-04 - accuracy: 1.0000 - val_loss: 0.0263 - val_accuracy: 0.9930
# Epoch 161/500
# 10/10 [==============================] - 0s 12ms/step - loss: 4.9823e-04 - accuracy: 1.0000 - val_loss: 0.0263 - val_accuracy: 0.9930
# Epoch 162/500
# 10/10 [==============================] - 0s 12ms/step - loss: 4.9055e-04 - accuracy: 1.0000 - val_loss: 0.0264 - val_accuracy: 0.9930
# Epoch 163/500
# 10/10 [==============================] - 0s 12ms/step - loss: 4.8377e-04 - accuracy: 1.0000 - val_loss: 0.0264 - val_accuracy: 0.9930
# Epoch 164/500
# 10/10 [==============================] - 0s 13ms/step - loss: 4.7680e-04 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9930
# Epoch 165/500
# 10/10 [==============================] - 0s 13ms/step - loss: 4.7015e-04 - accuracy: 1.0000 - val_loss: 0.0260 - val_accuracy: 0.9930
# Epoch 166/500
# 10/10 [==============================] - 0s 12ms/step - loss: 4.6309e-04 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9930
# Epoch 167/500
# 10/10 [==============================] - 0s 12ms/step - loss: 4.5658e-04 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9930
# Epoch 168/500
# 10/10 [==============================] - 0s 12ms/step - loss: 4.5038e-04 - accuracy: 1.0000 - val_loss: 0.0260 - val_accuracy: 0.9930
# Epoch 169/500
# 10/10 [==============================] - 0s 12ms/step - loss: 4.4389e-04 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 0.9930
# Epoch 170/500
# 10/10 [==============================] - 0s 13ms/step - loss: 4.3750e-04 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9930
# Epoch 171/500
# 10/10 [==============================] - 0s 13ms/step - loss: 4.3130e-04 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9930
# Epoch 172/500
# 10/10 [==============================] - 0s 11ms/step - loss: 4.2555e-04 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 0.9930
# Epoch 173/500
# 10/10 [==============================] - 0s 12ms/step - loss: 4.2016e-04 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 0.9930
# Epoch 174/500
# 10/10 [==============================] - 0s 12ms/step - loss: 4.1487e-04 - accuracy: 1.0000 - val_loss: 0.0257 - val_accuracy: 0.9930
# Epoch 175/500
# 10/10 [==============================] - 0s 12ms/step - loss: 4.0856e-04 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9930
# Epoch 176/500
# 10/10 [==============================] - 0s 11ms/step - loss: 4.0327e-04 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9930
# Epoch 177/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.9792e-04 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 0.9930
# Epoch 178/500
# 10/10 [==============================] - 0s 13ms/step - loss: 3.9229e-04 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9930
# Epoch 179/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.8704e-04 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 0.9930
# Epoch 180/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.8198e-04 - accuracy: 1.0000 - val_loss: 0.0254 - val_accuracy: 0.9930
# Epoch 181/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.7695e-04 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 0.9930
# Epoch 182/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.7197e-04 - accuracy: 1.0000 - val_loss: 0.0253 - val_accuracy: 0.9930
# Epoch 183/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.6689e-04 - accuracy: 1.0000 - val_loss: 0.0254 - val_accuracy: 0.9930
# Epoch 184/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.6231e-04 - accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 0.9930
# Epoch 185/500
# 10/10 [==============================] - 0s 13ms/step - loss: 3.5751e-04 - accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 0.9930
# Epoch 186/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.5328e-04 - accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 0.9930
# Epoch 187/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.4871e-04 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 0.9930
# Epoch 188/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.4416e-04 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 0.9930
# Epoch 189/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.3998e-04 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 0.9930
# Epoch 190/500
# 10/10 [==============================] - 0s 13ms/step - loss: 3.3608e-04 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 0.9930
# Epoch 191/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.3188e-04 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 0.9930
# Epoch 192/500
# 10/10 [==============================] - 0s 13ms/step - loss: 3.2712e-04 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 0.9930
# Epoch 193/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.2349e-04 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 0.9930
# Epoch 194/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.1964e-04 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 0.9930
# Epoch 195/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.1545e-04 - accuracy: 1.0000 - val_loss: 0.0248 - val_accuracy: 0.9930
# Epoch 196/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.1168e-04 - accuracy: 1.0000 - val_loss: 0.0247 - val_accuracy: 0.9930
# Epoch 197/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.0803e-04 - accuracy: 1.0000 - val_loss: 0.0247 - val_accuracy: 0.
- accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9937
# Epoch 252/500
# 10/10 [==============================] - 0s 14ms/step - loss: 1.6964e-04 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9937
# Epoch 253/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.6793e-04 - accuracy: 1.0000 - val_loss: 0.0232 - val_accuracy: 0.9937
# Epoch 254/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.6637e-04 - accuracy: 1.0000 - val_loss: 0.0232 - val_accuracy: 0.9937
# Epoch 255/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.6476e-04 - accuracy: 1.0000 - val_loss: 0.0232 - val_accuracy: 0.9937
# Epoch 256/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.6316e-04 - accuracy: 1.0000 - val_loss: 0.0232 - val_accuracy: 0.9937
# Epoch 257/500
# 10/10 [==============================] - 0s 13ms/step - loss: 1.6161e-04 - accuracy: 1.0000 - val_loss: 0.0232 - val_accuracy: 0.9937
# Epoch 258/500
# 10/10 [==============================] - 0s 11ms/step - loss: 1.6006e-04 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9937
# Epoch 259/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.5849e-04 - accuracy: 1.0000 - val_loss: 0.0232 - val_accuracy: 0.9937
# Epoch 260/500
# 10/10 [==============================] - 0s 11ms/step - loss: 1.5706e-04 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9937
# Epoch 261/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.5548e-04 - accuracy: 1.0000 - val_loss: 0.0232 - val_accuracy: 0.9937
# Epoch 262/500
# 10/10 [==============================] - 0s 13ms/step - loss: 1.5396e-04 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9937
# Epoch 263/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.5258e-04 - accuracy: 1.0000 - val_loss: 0.0232 - val_accuracy: 0.9937
# Epoch 264/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.5111e-04 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9937
# Epoch 265/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.4973e-04 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9937
# Epoch 266/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.4843e-04 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9937
# Epoch 267/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.4702e-04 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9937
# Epoch 268/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.4574e-04 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9937
# Epoch 269/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.4430e-04 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9937
# Epoch 270/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.4301e-04 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9937
# Epoch 271/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.4180e-04 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9937
# Epoch 272/500
# 10/10 [==============================] - 0s 13ms/step - loss: 1.4059e-04 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9945
# Epoch 273/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.3910e-04 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9937
# Epoch 274/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.3781e-04 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9937
# Epoch 275/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.3663e-04 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9937
# Epoch 276/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.3541e-04 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9945
# Epoch 277/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.3402e-04 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9945
# Epoch 278/500
# 10/10 [==============================] - 0s 13ms/step - loss: 1.3285e-04 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9945
# Epoch 279/500
# 10/10 [==============================] - 0s 11ms/step - loss: 1.3177e-04 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9945
# Epoch 280/500
# 10/10 [==============================] - 0s 13ms/step - loss: 1.3062e-04 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9945
# Epoch 281/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.2936e-04 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9945
# Epoch 282/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.2825e-04 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9945
# Epoch 283/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.2713e-04 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9937
# Epoch 284/500
# 10/10 [==============================] - 0s 13ms/step - loss: 1.2600e-04 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9945
# Epoch 285/500
# 10/10 [==============================] - 0s 13ms/step - loss: 1.2490e-04 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9937
# Epoch 286/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.2375e-04 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9945
# Epoch 287/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.2273e-04 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 0.9945
# Epoch 288/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.2163e-04 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 0.9945
# Epoch 289/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.2059e-04 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 0.9945
# Epoch 290/500
# 10/10 [==============================] - 0s 13ms/step - loss: 1.1949e-04 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 0.9945
# Epoch 291/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.1852e-04 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 0.9945
# Epoch 292/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.1748e-04 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 0.9945
# Epoch 293/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.1647e-04 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 0.9945
# Epoch 294/500
# 10/10 [==============================] - 0s 13ms/step - loss: 1.1546e-04 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 0.9945
# Epoch 295/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.1447e-04 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 0.9945
# Epoch 296/500
# 10/10 [==============================] - 0s 13ms/step - loss: 1.1352e-04 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 0.9945
# Epoch 297/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.1253e-04 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 0.9945
# Epoch 298/500
# 10/10 [==============================] - 0s 13ms/step - loss: 1.1160e-04 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 0.9945
# Epoch 299/500
# 10/10 [==============================] - 0s 13ms/step - loss: 1.1066e-04 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 0.9945
# Epoch 300/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.0974e-04 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 0.9945
# Epoch 301/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.0877e-04 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9945
# Epoch 302/500
# 10/10 [==============================] - 0s 13ms/step - loss: 1.0790e-04 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9945
# Epoch 303/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.0693e-04 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9945
# Epoch 304/500
# 10/10 [==============================] - 0s 12ms/step - loss: 1.0605e-04 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.
-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 437/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.9407e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 438/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.9130e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 439/500
# 10/10 [==============================] - 0s 13ms/step - loss: 3.8889e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 440/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.8644e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 441/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.8375e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 442/500
# 10/10 [==============================] - 0s 13ms/step - loss: 3.8096e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 443/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.7841e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 444/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.7591e-05 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9953
# Epoch 445/500
# 10/10 [==============================] - 0s 13ms/step - loss: 3.7350e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 446/500
# 10/10 [==============================] - 0s 13ms/step - loss: 3.7079e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 447/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.6858e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 448/500
# 10/10 [==============================] - 0s 13ms/step - loss: 3.6617e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 449/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.6356e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 450/500
# 10/10 [==============================] - 0s 13ms/step - loss: 3.6105e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 451/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.5887e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 452/500
# 10/10 [==============================] - 0s 11ms/step - loss: 3.5657e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 453/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.5416e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 454/500
# 10/10 [==============================] - 0s 13ms/step - loss: 3.5171e-05 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9953
# Epoch 455/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.4942e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 456/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.4708e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 457/500
# 10/10 [==============================] - 0s 14ms/step - loss: 3.4501e-05 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9953
# Epoch 458/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.4260e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 459/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.4051e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 460/500
# 10/10 [==============================] - 0s 14ms/step - loss: 3.3806e-05 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9953
# Epoch 461/500
# 10/10 [==============================] - 0s 13ms/step - loss: 3.3571e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9961
# Epoch 462/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.3361e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 463/500
# 10/10 [==============================] - 0s 13ms/step - loss: 3.3138e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953
# Epoch 464/500
# 10/10 [==============================] - 0s 12ms/step - loss: 3.2927e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9953

# %%
Y_hat = model.predict([X_test_encoder, Y_test_decoder_input])
# Out:
# 7/7 [==============================] - 1s 79ms/step

# %%
def translate(text):
    encoder_input = tokenizer.texts_to_sequences([text]) 
    encoder_input = pad_sequences(encoder_input, maxlen=8, padding='post', truncating='post', dtype='float32')
    
    T_y = 8
    decoder_input = np.zeros([1, T_y])
    word = '<start>'
    idx = tokenizer.word_index[word]
    
    translated_text = ''
    for t in range(T_y):
        translated_text += word + ' '
        decoder_input[0, t] = idx
        y_hat = model.predict([encoder_input, decoder_input])
        idx = np.argmax(y_hat[0, t, :])
        word = tokenizer.index_word[idx]
        if word == '<end>':
            translated_text += word + ' '
            break

    return translated_text

# %%
def generate_sample_translations():
    indices = np.random.choice(200, 5, replace=False)
    for i in range(5):    
        text = test_source[indices[i]]
        translated_text = translate(text)
        print ("----------------")
        print ("French text:", test_source[indices[i]])
        print ("Translation:", translated_text)
        print ("Ground truth:", test_target[indices[i]])

    return None

generate_sample_translations()
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# ----------------
# French text: <start> neuf cent quatre-vingt-six <end>
# Translation: <start> nine hundred and eighty six <end>
# Ground truth: <start> nine hundred and eighty-six <end>
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# ----------------
# French text: <start> six cent soixante-neuf <end>
# Translation: <start> six hundred and sixty nine <end>
# Ground truth: <start> six hundred and sixty-nine <end>
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# ----------------
# French text: <start> six cent trente-sept <end>
# Translation: <start> six hundred and thirty seven <end>
# Ground truth: <start> six hundred and thirty-seven <end>
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# ----------------
# French text: <start> sept cent quarante-deux <end>
# Translation: <start> seven hundred and forty two <end>
# Ground truth: <start> seven hundred and forty-two <end>
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# ----------------
# French text: <start> huit cent quatre-vingt-quatorze <end>
# Translation: <start> eight hundred and ninety four <end>
# Ground truth: <start> eight hundred and ninety-four <end>
